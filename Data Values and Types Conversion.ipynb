# %%
import pandas as pd
df=pd.read_csv('dataset/Pokemon.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total    HP  Attack
# 0      1              Bulbasaur    Grass  Poison    318  45.0    49.0  \
# 1      2                Ivysaur    Grass  Poison    405  60.0    62.0
# 2      3               Venusaur    Grass  Poison    525   NaN    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80.0     NaN
# 4      4             Charmander     Fire     NaN    309  39.0    52.0
# ..   ...                    ...      ...     ...    ...   ...     ...
# 795  719                Diancie     Rock   Fairy    600  50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80.0   110.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80.0   160.0
# 799  721              Volcanion     Fire   Water    600  80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65     65.0     45           1      False
# ...

# %%
#lamdba with constant values
#apply + lamdba

df['newcol']=df.Speed.apply(lambda x:x*10)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol
# 0       65     65.0     45           1      False     450
# 1       80      NaN     60           1      False     600
# 2      100    100.0     80           1      False     800
# 3      122    120.0     80           1      False     800
# 4       60     50.0     65           1      False     650

# %%
def myfun(x):
    return x+10

df['newcol1']=df.HP.apply(myfun)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol  newcol1
# 0       65     65.0     45           1      False     450     55.0
# 1       80      NaN     60           1      False     600     70.0
# 2      100    100.0     80           1      False     800      NaN
# 3      122    120.0     80           1      False     800     90.0
# 4       60     50.0     65           1      False     650     49.0

# %%
#lambda with condition
#>50 0
#<50 1

df['newcol2']=df['Defense'].apply(lambda x: 0 if x>50 else 1 )

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 0  1  Bulbasaur  Grass  Poison    318  45.0    49.0       49       65  \
# 1  2    Ivysaur  Grass  Poison    405  60.0    62.0       63       80
#
#    Sp. Def  Speed  Generation  Legendary  newcol  newcol1  newcol2
# 0     65.0     45           1      False     450     55.0        1
# 1      NaN     60           1      False     600     70.0        0

# %%
#total > 300 0
# <300 1
df['newcol3'] = df["Total"].apply(lambda x:1 if x<300 else 1)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol  newcol1  newcol2
# 0       65     65.0     45           1      False     450     55.0        1  \
# 1       80      NaN     60           1      False     600     70.0        0
# 2      100    100.0     80           1      False     800      NaN        0
# 3      122    120.0     80           1      False     800     90.0        0
# 4       60     50.0     65           1      False     650     49.0        1
#
#    newcol3
# 0        1
# 1        1
# 2        1
# 3        1
# ...

# %%
df.drop('newcol',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 0  1  Bulbasaur  Grass  Poison    318  45.0    49.0       49       65  \
# 1  2    Ivysaur  Grass  Poison    405  60.0    62.0       63       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0     65.0     45           1      False
# 1      NaN     60           1      False

# %%
df.drop(['newcol1','newcol2','newcol3'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk
# 0  1  Bulbasaur  Grass  Poison    318  45.0    49.0       49       65  \
# 1  2    Ivysaur  Grass  Poison    405  60.0    62.0       63       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0     65.0     45           1      False
# 1      NaN     60           1      False

# %%
#total 
#<100 -1
#> 100 0
# >200 1
# >300 2
#userdefined function
#lambda cannot be used if the condtion is more than 2

def changeValue(value):
    if value<100:
        return -1
    elif value>300:
        return 0
    elif value>200:
        return 1
    elif value>100:
        return 2
    

df['newcol3'] = df["Total"].apply(changeValue)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol3
# 0       65     65.0     45           1      False        2
# 1       80      NaN     60           1      False        2
# 2      100    100.0     80           1      False        2
# 3      122    120.0     80           1      False        2
# 4       60     50.0     65           1      False        2

# %%
df['newcol3'].value_counts()
# Out:
# newcol3
# 2    679
# 1    111
# 0     10
# Name: count, dtype: int64

# %%
df['meanvalue']=df[['HP','Total','Attack']].apply(lambda x: (x[0]+x[1]+x[2])/3,axis=1)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol3   meanvalue
# 0       65     65.0     45           1      False        2  137.333333
# 1       80      NaN     60           1      False        2  175.666667
# 2      100    100.0     80           1      False        2         NaN
# 3      122    120.0     80           1      False        2         NaN
# 4       60     50.0     65           1      False        2  133.333333

# %%
#Speed + HP >100 = 0
#           <100 =1

df['newcol']=df[['Speed','HP']].apply(lambda x: 0 if x[0]+x[1]>100 else 1,axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol3   meanvalue  newcol
# 0       65     65.0     45           1      False        2  137.333333       1
# 1       80      NaN     60           1      False        2  175.666667       0
# 2      100    100.0     80           1      False        2         NaN       1
# 3      122    120.0     80           1      False        2         NaN       0
# 4       60     50.0     65           1      False        2  133.333333       0

# %%
def changeFun(x):
    if x[0]+x[1]>100:
        return 0
    else:
        return 1
    
df['newcol']=df[['Speed','HP']].apply(changeFun,axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total    HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45.0    49.0       49  \
# 1  2                Ivysaur  Grass  Poison    405  60.0    62.0       63
# 2  3               Venusaur  Grass  Poison    525   NaN    82.0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80.0     NaN      123
# 4  4             Charmander   Fire     NaN    309  39.0    52.0       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol3   meanvalue  newcol
# 0       65     65.0     45           1      False        2  137.333333       1
# 1       80      NaN     60           1      False        2  175.666667       0
# 2      100    100.0     80           1      False        2         NaN       1
# 3      122    120.0     80           1      False        2         NaN       0
# 4       60     50.0     65           1      False        2  133.333333       0

# %%
df.dtypes
# Out:
# #               int64
# Name           object
# Type 1         object
# Type 2         object
# Total           int64
# HP            float64
# Attack        float64
# Defense         int64
# Sp. Atk         int64
# Sp. Def       float64
# Speed           int64
# Generation      int64
# Legendary        bool
# newcol3         int64
# meanvalue     float64
# newcol          int64
# dtype: object

# %%
sales=pd.read_csv('dataset/sales_data_types.csv')
sales.head()
# Out:
#    Customer Number     Customer Name         2016          2017
# 0          10002.0  Quest Industries  $125,000.00    $162500.00  \
# 1         552278.0    Smith Plumbing  $920,000.00  $101,2000.00
# 2          23477.0   ACME Industrial   $50,000.00     $62500.00
# 3          24900.0        Brekke LTD  $350,000.00    $490000.00
# 4         651029.0         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
sales.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016                object
# 2017                object
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
#data type conversion
#pd.to_numeric()
#pd.to_datetime()

pd.to_numeric(sales['2016'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\datascience\lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$125,000.00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       1 #data type conversion
#       2 #pd.to_numeric()
#       3 #pd.to_datetime()
# ----> 5 pd.to_numeric(sales['2016'])
#
# File ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
# ...

# %%
value="$250,000"
value=value.replace("$","").replace(',','')
value
# Out:
# '250000'

# %%
#values => correct type
#apply +lambda (user_defiend)

sales['2016']=sales['2016'].apply(lambda x: x.replace("$","").replace(",",""))

#2017
#Percent Growth

# %%
sales
# Out:
#    Customer Number     Customer Name       2016          2017 Percent Growth
# 0          10002.0  Quest Industries  125000.00    $162500.00         30.00%  \
# 1         552278.0    Smith Plumbing  920000.00  $101,2000.00         10.00%
# 2          23477.0   ACME Industrial   50000.00     $62500.00         25.00%
# 3          24900.0        Brekke LTD  350000.00    $490000.00          4.00%
# 4         651029.0         Harbor Co   15000.00     $12750.00        -15.00%
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %%
sales['2016']=pd.to_numeric(sales['2016'])

# %%
sales.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016               float64
# 2017                object
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
sales['2017']=sales['2017'].apply(lambda x: x.replace("$","").replace(",",""))
sales['2017']=pd.to_numeric(sales['2017'])

# %%
sales.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016               float64
# 2017               float64
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
sales.head(2)
# Out:
#    Customer Number     Customer Name      2016       2017 Percent Growth
# 0          10002.0  Quest Industries  125000.0   162500.0         30.00%  \
# 1         552278.0    Smith Plumbing  920000.0  1012000.0         10.00%
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y

# %%
sales['Percent Growth']=sales['Percent Growth'].apply(lambda x: x.replace("%",""))
sales['Percent Growth']=pd.to_numeric(sales['Percent Growth'])/100

# %%
sales
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30  \
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year Active
# 0       500      1   10  2015      Y
# 1       700      6   15  2014      Y
# 2       125      3   29  2016      Y
# 3        75     10   27  2015      Y
# 4    Closed      2    2  2014      N

# %%
sales['2016Percent']=sales['2016']*sales['Percent Growth']

# %%
sales
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30  \
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year Active  2016Percent
# 0       500      1   10  2015      Y      37500.0
# 1       700      6   15  2014      Y      92000.0
# 2       125      3   29  2016      Y      12500.0
# 3        75     10   27  2015      Y      14000.0
# 4    Closed      2    2  2014      N      -2250.0

# %%
sales['2016Percent']=sales[['2016','Percent Growth']].apply(lambda x: x[0]*x[1],axis=1)

# %%
sales['2017Percent']=sales[['2017','Percent Growth']].apply(lambda x: x[0]*x[1],axis=1)

# %%
sales
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth
# 0          10002.0  Quest Industries  125000.0   162500.0            0.30  \
# 1         552278.0    Smith Plumbing  920000.0  1012000.0            0.10
# 2          23477.0   ACME Industrial   50000.0    62500.0            0.25
# 3          24900.0        Brekke LTD  350000.0   490000.0            0.04
# 4         651029.0         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year Active  2016Percent  2017Percent
# 0       500      1   10  2015      Y      37500.0      48750.0
# 1       700      6   15  2014      Y      92000.0     101200.0
# 2       125      3   29  2016      Y      12500.0      15625.0
# 3        75     10   27  2015      Y      14000.0      19600.0
# 4    Closed      2    2  2014      N      -2250.0      -1912.5

# %%
sales=pd.read_csv('dataset/Sales_Data/Sales_April_2019.csv')
sales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each
# 0   176558        USB-C Charging Cable                2      11.95  \
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
sales.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
len(sales)
# Out:
# 18383

# %%
sales.dropna(inplace=True)

# %%
sales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each
# 0   176558        USB-C Charging Cable                2      11.95  \
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
pd.to_numeric(sales['Quantity Ordered'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\datascience\lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Quantity Ordered"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 pd.to_numeric(sales['Quantity Ordered'])
#
# File ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
# ...

# %%
sales=sales[sales['Quantity Ordered']!='Quantity Ordered']

# %%
sales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each
# 0   176558        USB-C Charging Cable                2      11.95  \
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
sales['Quantity Ordered']=pd.to_numeric(sales['Quantity Ordered'])

# %%
sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered     int64
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
sales['Price Each']=pd.to_numeric(sales['Price Each'])

# %%
sales['Order Date']=pd.to_datetime(sales['Order Date'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7992\3911741685.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Order Date']=pd.to_datetime(sales['Order Date'])

# %%
sales.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
sales['Amount']=sales['Quantity Ordered']*sales['Price Each']

# %%
sales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each
# 0   176558        USB-C Charging Cable                 2       11.95  \
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Amount
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001   11.99

# %%
value='917 1st St, Dallas, TX 75001'
value.split(',')[1].strip()
# Out:
# 'Dallas'

# %%
sales['City']=sales['Purchase Address'].apply(lambda x: x.split(',')[1].strip())

# %%
sales
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each
# 0       176558        USB-C Charging Cable                 2       11.95  \
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 18378   194090                Google Phone                 1      600.00
# 18379   194091       AA Batteries (4-pack)                 1        3.84
# 18380   194092      AAA Batteries (4-pack)                 2        2.99
# 18381   194093       AA Batteries (4-pack)                 1        3.84
# 18382   194094    Lightning Charging Cable                 1       14.95
#
#                Order Date                        Purchase Address  Amount
# ...

# %%
sales.to_csv('dataset/clean_sales_data.csv')
